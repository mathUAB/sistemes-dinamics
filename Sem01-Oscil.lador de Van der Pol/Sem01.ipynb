# %% [markdown]
# ## Atractor de Lorenz

# %%
reset()

# %%
var('x y z t')
# Out:
# (x, y, z, t)

# %%
import numpy as np
import matplotlib.pyplot as plt

def op(x0, y0, z0, T, plane=False):
    sigma=10
    rho=100.5
    beta=8/3
    # The Lorenz equations
    lorenz=[sigma*(y-x), x*(rho-z)-y, x*y-beta*z]
    # Time and initial conditions
    h=0.001
    tmax=T
    ics=[0,x0, y0, z0]
    sol=desolve_system_rk4(lorenz,[x,y,z],ics = ics,ivar = t,step = h, end_points=[0,tmax])
    Q2=[[j,k,l] for i,j,k,l in sol]
    p2 = line3d(Q2)
    p3 = parametric_plot3d([8,x,y], urange=(7,9), vrange= (23,26), color="red", opacity=0.5)
    if plane: 
        return (p2 + p3)
    return p2

def lorenz(xyz, *, s=10, r=100.5, b=8/3):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return np.array([x_dot, y_dot, z_dot])

def op_matplot(x0, y0, z0, T, dt):
    num_steps = ceil(T/dt)

    xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
    xyzs[0] = (x0, y0, z0)  # Set initial values
    # Step through "time", calculating the partial derivatives at the current point
    # and using them to estimate the next point
    for i in range(num_steps):
        xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

    # Plot
    ax = plt.figure().add_subplot(projection='3d')

    ax.plot(*xyzs.T, lw=0.5)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    
    return plt

# %% [markdown]
# #### Part 1

# %%
x0, y0, z0, T = 0,4.25542256030734, 74.6507735095562, 1.1
op(x0, y0, z0, T)
# Out:
# Graphics3d Object

# %%
prec = 0.00001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-100.5.pdf", format="pdf", bbox_inches="tight")
# Out:
# /tmp/ipykernel_5647/3134548877.py:53: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   ax = plt.figure().add_subplot(projection='3d')

# %% [markdown]
# #### Part 2

# %%
import numpy as np
import matplotlib.pyplot as plt

def op(x0, y0, z0, T, plane=False):
    sigma=10
    rho=25
    beta=8/3
    # The Lorenz equations
    lorenz=[sigma*(y-x), x*(rho-z)-y, x*y-beta*z]
    # Time and initial conditions
    h=0.001
    tmax=T
    ics=[0,x0, y0, z0]
    sol=desolve_system_rk4(lorenz,[x,y,z],ics = ics,ivar = t,step = h, end_points=[0,tmax])
    Q2=[[j,k,l] for i,j,k,l in sol]
    p2 = line3d(Q2)
    p3 = parametric_plot3d([8,x,y], urange=(7,9), vrange= (23,26), color="red", opacity=0.5)
    if plane: 
        return (p2 + p3)
    return p2

def lorenz(xyz, *, s=10, r=25, b=8/3):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return np.array([x_dot, y_dot, z_dot])

def op_matplot(x0, y0, z0, T, dt):
    num_steps = ceil(T/dt)

    xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
    xyzs[0] = (x0, y0, z0)  # Set initial values
    # Step through "time", calculating the partial derivatives at the current point
    # and using them to estimate the next point
    for i in range(num_steps):
        xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

    # Plot
    ax = plt.figure().add_subplot(projection='3d')

    ax.plot(*xyzs.T, lw=0.5)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    
    return plt

# %% [markdown]
# ##### 1 op

# %%
x0, y0, z0, T = 8, 14.3567617972399, 10.7371471057186, 3.277811123
op(x0, y0, z0, T)
# Out:
# Graphics3d Object

# %%
prec = 0.00001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-1.pdf", format="pdf", bbox_inches="tight")

# %%
x0, y0, z0, T = 8, 0.222435807233156e-2, 32.1730717357650, 1.693439189
p2=op(x0, y0, z0, T)

# %%
prec = 0.00001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-2.pdf", format="pdf", bbox_inches="tight")

# %%
x0, y0, z0, T = 8, -2.36504985729125, 33.9153581022303, 4.778134392
op(x0, y0, z0, T)
# Out:
# Graphics3d Object

# %%
prec = 0.000001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-3.pdf", format="pdf", bbox_inches="tight")

# %%
x0, y0, z0, T = -8, -14.3567617972399, 10.7371471057186, 3.277811123
op(x0, y0, z0, T)
# Out:
# Graphics3d Object

# %%
prec = 0.00001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-4.pdf", format="pdf", bbox_inches="tight")

# %%
x0, y0, z0, T = -8, -0.222435807233156e-2, 32.1730717357650, 1.693439189
p1 = op(x0, y0, z0, T)

# %%
prec = 0.00001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-5.pdf", format="pdf", bbox_inches="tight")

# %%
x0, y0, z0, T = -8, 2.36504985729125, 33.9153581022303, 4.778134392
op(x0, y0, z0, T)
# Out:
# Graphics3d Object

# %%
prec = 0.000001
op_matplot(x0, y0, z0, T, prec).savefig("latex/Images/op3-25-6.pdf", format="pdf", bbox_inches="tight")

# %%
p1+p2
# Out:
# Graphics3d Object
